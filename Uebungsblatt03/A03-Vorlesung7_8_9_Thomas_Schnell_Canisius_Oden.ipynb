# %% [markdown]
# Before you turn this problem in, make sure everything runs as expected. First, **restart the kernel** (in the menubar, select Kernel$\rightarrow$Restart) and then **run all cells** (in the menubar, select Cell$\rightarrow$Run All).
#
# Make sure you fill in any place that says `YOUR CODE HERE` or "YOUR ANSWER HERE", as well as your name and collaborators below:

# %%
NAME = "Oden"
COLLABORATORS = "Thomas, Schnell, Canisius"

# %% [markdown]
# ---

# %% [markdown]
# # Vorlesung 07

# %% [markdown]
# 1. Welche der folgenden Begriffe sind Kriterien für die Evaluation eines Datenbankentwurfs? (2 Punkte) <br>
#     a. Speicherplatzbedarf
#
#     b. Weniger Tabellen
#
#     c. Zugriffseffizienz
#
#     d. Änderungsfreundlichkeit

# %% [markdown]
# a) Speicherplatzbedarf: Optimierung des Speicherverbrauchs (sollte so effizient sein, dass unnötige Kosten und Ressourcenverbrauch vermieden werden kann)
#
# b) weniger Tabellen: kein notwendiges Kriterium, da der Entwurf nicht imm erdurch die Anzahl der Tabellen optimiert werden sollte. Tabellenstruktur sollte angemessen gestaltet werden, da mehr Tabellen notwendig sein können, um Daten normalisiert und redundanzfrei darzustellen.
#
# c) Zugriffseffizienz: schneller Zugriff auf häufig genutzte Daten (der Entwurf sollte so gestaltet sein, dass die Daten schnell und effizient abgerufen werden können)
#
# d) Änderungsfreundlichkeit: einfache Anpassung und Erweiterungen (sorgt dafür das sie langfristig wartbar bleibt)
#
# => Kriterien a) c) d)

# %% [markdown]
# 2. Ordnen sie die Konzepte des ER-Modells den Konzepten des relationalen Modells zu (4 Punkte)
#
# ER-Modell
#
# 1. Entitätentyp
# 2. (1:1) oder (1:N)-Beziehungstyp
# 3. (M:N)-Beziehungstyp
# 4. n-ärer Beziehungstyp
# 5. Einfaches Attribut
# 6. Zusammengesetztes Attribut
# 7. Mehrwertiges Attribut
# 8. Schlüsselattribut
#
#
# Relationales Modell
#
# a. Attribut <br>
# b. Primär- (oder Sekundär)schlüssel <br>
# c. Fremdschlüssel oder Relation <br>
# d. Relation mit n Fremdschlüsseln <br>
# e. Menge der Komponentenatribute <br>
# f. Relation und Fremdschlüssel <br>
# g. Relation <br>
# h. Relation mit zwei Fremdschlüsseln <br>

# %% [markdown]
# 1 -> g (Entitättyp -> Relation)
#
# 2 -> c (1:1 / 1:N -> Fremdschlüssel oder Relation)
#
# 3 -> h (M:N -> Relation mit zwei Fremdschlüsseln)
#
# 4 -> d (n-äre Beziehung -> Relation mit mehreren Fremdschlüsseln)
#
# 5 -> a (Einfaches Attribut -> Attribut)
#
# 6 -> e (Zusammengesetztes Attribut -> Menge der Komponentenattribute)
#
# 7 -> f (Mehrwertiges Attrivut -> Relation und Fremdschlüssel)
#
# 8 -> b (Schlüsselattribut -> Primär- oder Sekundärschlüssel)

# %% [markdown]
# 3. Geben Sie zu den folgenden Beziehungen sinnvolle Kardinalitäten an. Geben Sie zusätzlich an, ob die Beziehung optional oder verpflichtend ist (Min-Max-Beschränkungen, Notation siehe Vorlesung) und begründen Sie die von ihnen gewählten Kardinaliäten. (8 Punkte) <br> 1. Angestellter -arbeitet in- Abteilung <br> 2. Abteilung -besitzt-Arbeitsgruppe- <br> 3. Angestellter -leitet- Arbeitsgruppe <br> 4. Abteilung -arbeitet an- Projekt

# %% [markdown]
# 1. N (0,1) : 1 (0,*) (ein Angestellter arbeitet in einer Abteilung und eine Abteilung hat mehrere Angestellte)
# 2. 1 (0,*) : N (0,1) (eine Abteilung hat mehrere Angestellte und ein Angestellter arbeitet in einer Abteilung)
# 3. 1 (0,1) : 1 (0,1) (Ein Angestelter leitet eine Arbeitsgruppe und eine Arbeitsgruppe wird von einem Angestellten geleitet)
# 4. 1 (0,1): N(0,*) (Eine Abteilung arbeitet an mehreren Projekten und ein Projekt wird von einer Abteilung bearbeitet)

# %% [markdown]
# 4. Die Beziehungen und Entitätstypen aus 3. gehören zu einer gemeinsamen Miniwelt und sollen nun in ein relationales Schema überführt werden.
#
# a. Geben Sie für jeden Entitätstyp die notwendigen Primär- und Fremdschlüssel (treffen bzw. wählen Sie sinnvolle Bezeichnungen) in der zugehörigen Relation an. <br> b. Geben Sie an, wie sie die 4 obigen Beziehungen im relationalen Modell umsetzen würden. Gehen sie inbsondere eventuelle weitere Relationen zusätzlich zu den Entitätstypen an, die gebraucht werden (8 Punkte)

# %% [markdown]
# a)
#
# Entitätstyp: Angestellter Primärschlüssel: Angestellten-ID Attribute: Angestellten-ID,
# VName,NName, etc. Fremdschlüssel: Abteilungs-ID Entitätstyp: Abteilung Primärschlüssel:
# Abteilungs-ID Attribute: Abteilungs-ID, Standort, etc. Fremdschlüssel: Entitätstyp: Arbeitsgruppe Primärschlüssel: Arbeitsgruppe-ID Attribute: Arbeitsgruppe-ID, Bezeichnung, etc. Fremdschlüssel: Abteilungs-ID, Angestellten-ID Entitätstyp: Projekt Primärschlüssel: Projekt-ID Attribute: Projekt-ID, PName, Dauer, etc. Fremdschlüssel: Abteilungs-ID
#
# b)
#
# Angestellter arbeitet in Abteilung: n-1-Beziehung: Mehrere Angestellten können in einer
# Abteilung arbeiten.
#
# Abteilung besitzt Arbeitsgruppe: 1-n-Beziehung: Eine Abteilung besitzt mehrer Arbeitsgruppen,
# eine Arbeitsgruppe besitzt nur eine Abteilung.
#
# Angestellter leitet Arbeitsgruppe: 1-1-Beziehung: Ein Angestellter kann eine Arbeitsgruppe
# leiten, eine Arbeitsgruppe wird von einem Angetellten geleitet.
#
# Abteilung arbeitet an Projekt: N-M-Beziehung: Eine Abteilung arbeitet an mehreren Projekten, an
# einem Projekt wird von mehreren Abteilungen geleitet.
#
# Weitere Beziehungen: - man könnte n-m-Beziehziehnungen machen, damit man Abteilungsüber-
# greifend arbeiten könnte. - eine Beziehnung zwischen Arbeitsgruppe und Projekt, Eine Arbeits-
# gruppe arbeitet an einem Projekt, und an einem Projekt können mehrere Arbeitsgruppen arbeiten

# %% [markdown]
# 5. Überführen eines ER-Diagramms in ein relationales Schema
#
# Beispiel:
#
# <!-- ![ER_to_relation_exmaple.PNG](attachment:ER_to_relation_exmaple.PNG) -->
#
# <div>
# <img src="attachment:ER_to_relation_exmaple.PNG" width="350" align="left"/>
# </div>

# %% [markdown]
# - Unten ist ein ER-Diagramm gegeben. Zeichnen Sie die dazugehörige Tabellen <b>hier im Notebook</b>, indem Sie das Bild einfügen oder die Tabellen per HTML im Markdown modellieren (siehe Codebsp. unten) (7 Punkte)
# - Nennen Sie für jede Tabelle den Prmär- sowie alle Fremdschlüssel. (3 Punkte)
#
# | <u>Beispiel</u> | Tabelle |
# | --- | --- |
# | |
#
# <div>
# <img src="attachment:ER.PNG" width="600"/>
# </div>

# %% [markdown]
# Tabelle: CUSTOMER
# | <u>Customer-ID</u> | Name | Address | ZIP_code | Discount |
# | --- | --- | --- | --- | --- |
# | |

# %% [markdown]
# 6. Schreiben Sie das SQL-Statement, weleches zur Erzeugung der Tabelle ORDER notwendig ist. Nutzen Sie dabei insbesondere sinnvolle Datentypen für die Attribute und modellieren Sie die Primär- und Fremdschlüssel (4 Punkte)

# %% [markdown]
# CREATE TABLE ORDER ( \
#     Order_Number VARCHAR(10) NOT NULL, \
#     Order_date DATE NOT NULL, \
#     due_date DATE, \
#     Customer_ID VARCHAR(10) NOT NULL, \
#     PRIMARY KEY (Order_Number), \
#     FOREIGN KEY (Customer_ID) REFERENCES CUSTOMER(Customer_ID) \
# );

# %% [markdown]
# 7. Ordnen Sie die folgenden Varianten jeweils dem Vorteil oder Nachteil zu, den die gegebene Variante der Datenbankmodellierung mit sich bringt. (4 Punkte)
#
# Varianten:
# + Variante 1: Relationen für Ober- und Untertypen mit redundanten Attributen
# + Variante 2: Untertyp-Relation besitzt Primärschlüssel des Obertyps und spezifische (lokale) Attribute
# + Variante 3: Obertyp wird als Sicht realisiert
# + Variante 4: Einzelrelation für die Darstellung des Obertyps und dessen Untertypen
#
# Vorteil:
#
#     a. keine Duplizierung von Attributwerten
#     b. nur Schlüsselattribute werden redundant gespeichert
#     c. schnelle Zugriffszeit (keine Tabellenverknüpfung notwendig)
#     d. schnelle Zugriffszeit (keine Tabellenverknüpfung notwendig)
#
# Nachteil:
#
#     e. Zugriff auf Untertyp-Attribute ist langsamer (wegen Join)
#     f. erhöhter Platzbedarf, ggf. Inkonsistenzen (redundante Speicherung)
#     g. Nullwerte in Attributen, die Untertyp-spezifisch sind
#     h. Zugriff auf Obertyp-Attribute ist langsamer (wegen Projektion und Vereinigung)

# %% [markdown]
# Variante1: Vorteil C. nur Schlüsselattribute  werden redundant gespeichert Nachteil: f. erhöhter
# Platzbedarf, ggf. Inkonsistenzen
#
# Variante2: Vorteil: a. keine Duplizierung von Attributwerten Nachteil: e Nullwerte in Attributen,
# die Untertyp-spezifisch sind
#
# Variante3: Vorteil: a schnelle Zugriﬀszeit (keine Tabellenverknüpfung notwendig) Nachteil: h.
# Zugriﬀ auf Obertyp-Attribute ist langsamer (wegen Projektion und Vereinigung)
#
# Variante4: Vorteil: d. schnelle Zugriﬀszeit (keine Tabellenverknüpfung notwendig) Nachteil: g.
# Zugriﬀ auf Untertyp-Attribute ist langsamer (wegen Join)

# %% [markdown]
# # Vorlesung 08: Funktionale Abhängigkeiten und Normalisierung

# %% [markdown]
# 1. Welche der folgenden Kriterien können genutzt werden um zu beurteilen, ob ein Entwurf “besser” ist als ein anderer? (3 Punkte)
#
#     a. Klare Semantik (Bedeutung) der Relationen und Attribute
#
#     b. Zunahme von Nullwerten in Tupeln
#
#     c. Die Semantik der Beziehung und der Attribute kann einfacher erklärt werden
#
#     d. Reduzierung der redundanten Werte in Tupeln
#
#     e. Geben die Möglichkeit, falsche Tupel zu erzeugen
#
#     f. Attribute eines Relationsschemas sind mit einer bestimmten Bedeutung/Semantik assoziiert

# %% [markdown]
# a, d, e

# %% [markdown]
# 2. Erklären Sie warum die folgende Tabelle auf einen schlechten Entwurf hinweist. Gehen Sie dabei auch auf die Folgen ein. (3 Punkte)
#
#
# Tabelle 1: "STUDENT"
#
# |<u> Student\_ID </u>| Name     | Major            | MID | Faculty                                      | FID |
# | ----------- | -------- | ---------------- | --- | ------------------------------------------- | --- |
# | 1           | Egon     | Computer Science | M01 | Faculty of Mathematics and Natural Sciences | F01 |
# | 2           | Wolfgang | Biology          | M02 | Faculty of Mathematics and Natural Sciences | F01 |
# | 3           | Helmut   | Biology          | M02 | Faculty of Mathematics and Natural Sciences | F01 |
# | 4           | Heinz    | Computer Science | M01 | Faculty of Mathematics and Natural Sciences | F01 |
# | 5           | Felix    | Mathmatics       | M03 | Faculty of Mathematics and Natural Sciences | F01 |

# %% [markdown]
# Die Tabelle ist ein schlechter Entwurf, weil Informationen (Major, Major‑ID, Faculty, Faculty‑ID) mehrfach wiederholt werden. Dadurch entstehen Redundanz, Inkonsistenzen und die drei klassischen Anomalien: Update-, Insert- und Delete‑Anomalien.

# %% [markdown]
# 3. Welche Anomalie-Arten gibt es? Nennen sie diese beim Namen und beschreiben sie kurz die Art der Situationen, in denen sie Auftreten. (3 Punkte)

# %% [markdown]
# ### Änderungs‑/Update‑Anomalie
# Beschreibung: Eine in mehreren Tupeln gespeicherte Information muss an mehreren Stellen geändert werden. Tritt auf, wenn redundante Daten nicht konsistent aktualisiert werden.
# Situation: Änderung des Fakultätsnamens erfordert Update in allen Student‑Zeilen; vergisst man Zeilen, entstehen Inkonsistenzen.
#
# ### Einfüge‑/Insert‑Anomalie
# Beschreibung: Es ist nicht möglich, unabhängige Informationen sinnvoll zu speichern, ohne unvollständige Tupel (NULLs) oder Schein‑Tupel anzulegen.
# Situation: Man möchte einen neuen Studiengang oder eine neue Fakultät anlegen, hat aber noch keinen Studenten dafür — in der Tabelle lässt sich das nur mit NULLs oder Dummy‑Einträgen realisieren.
#
# ### Lösch‑/Delete‑Anomalie
# Beschreibung: Durch das Löschen eines Tupels werden unbeabsichtigt auch unabhängige Informationen gelöscht.
# Situation: Löscht man den letzten Studenten eines Majors, geht damit zugleich die Information über diesen Major/Fakultät verloren, obwohl diese weiterhin gültig sein sollte.

# %% [markdown]
# 4. Ist es möglich in der Datenbank aus Frage 2 (Tabelle 1: "STUDENT"), eine neue Fakultät "Kunst" (F02) einzufügen, die noch keinen Studierenden hat? Wenn ja, geben Sie die neue Zeile an, die in die Tabelle eingefügt werden soll. Wenn nein, erklären Sie warum dies nicht möglich ist. (2 Punkte)

# %% [markdown]
# Nicht sinnvoll möglich. Entweder man fügt einen Dummy/NULL‑Studenten ein (z.B. Student_ID=6, Name=NULL, Major=NULL, MID=NULL, Faculty=Kunst, FID=F02) — was inkonsistent ist oder man müsste eine seperate Faculty Relation Tabelle anlegen

# %% [markdown]
# 5. Führen Sie eine verlustlose Zerlegung der Relation "STUDENT" gemäß Tabelle 1 durch. (4 Punkte)

# %% [markdown]
# STUDENT(Student_ID PK, Name, MID FK) <br>
# MAJOR(MID PK, Major, FID FK)<br>
# FACULTY(FID PK, Faculty)

# %% [markdown]
# 6. Wenn {A1, A2, A3} ein minimaler Superschlüssel ist, kann {A1, A3} ein Superschlüssel sein? Geben Sie eine Ja/Nein Antwort und begründen Sie ihre Antwort. (2 Punkte)

# %% [markdown]
# Nein.
#
# Begründung: Ein minimaler Superschlüssel (Kandidatenschlüssel) ist per Definition ein Superschlüssel, von dem keine echte Teilmenge ebenfalls Superschlüssel ist. {A1,A3} wäre eine echte Teilmenge von {A1,A2,A3}; wäre {A1,A3} ein Superschlüssel, so wäre {A1,A2,A3} nicht mehr minimal – Widerspruch. Daher kann {A1,A3} nicht gleichzeitig Superschlüssel sein.

# %% [markdown]
# 7. Ist die in Tabelle 2 (GRADE) gegebene Relation, <br>
#         {Student_Number, Course_Number } -> Grade
#    eine volle FD (volle funktionale Abhängigkeit)? Geben Sie eine Ja/Nein Antwort und begründen Sie warum. (2 Punkte)
#
#
# Tabelle 2: GRADE
#
# | Student_Number | Course_Number   | Grade |
# | --- | ----- | ----- |
# | 001 | 3-245 | 86    |
# | 002 | 3-245 | 75    |
# | 003 | 3-245 | 68    |
# | 001 | 3-105 | 92    |

# %% [markdown]
# Ja, da nur das Paar {Student_Number, Course_Number} eindeutig die Note festlegt.

# %% [markdown]
# 8. Identifizieren Sie eine ***transitive FD*** der Tabelle 1 (STUDENT), zum Beispiel: A->B, es existiert Y, sodass A->Y und Y->B. Geben Sie A, B und Y in den von Ihnen identifizierten Abhängigkeiten an. (2 Punkte)

# %% [markdown]
# A = Student_ID, Y = MID, B = Major.
#
# Begründung: Aus der Tabelle gilt Student_ID → MID (z. B. 2 → M02) und MID → Major (M02 → Biology). Daher folgt transitiv Student_ID → Major (z. B. 2 → Biology). Diese transitive Abhängigkeit verletzt die 3. Normalform und verursacht Redundanz/Anomalien.

# %% [markdown]
# 9. Überführen Sie Tabelle 3 (REGISTRATION) in die erste Normalform (1NF). (3 Punkte)
#
# Tabelle 3: REGISTRATION
#
# | Student\_ID | Courses                                    |
# | ----------- | ------------------------------------------ |
# | 1           | Data Science, Computational Intelligence   |
# | 2           | Computational Intelligence, Linear Algebra |
# | 3           | Analysis, Linear Algebra, Astronomy        |
# | 4           | Astronomy, Data Science, Economics         |

# %% [markdown]
# REGISTRATION(Student_ID, Course) mit zusammengesetztem Primärschlüssel (Student_ID, Course).
# Also: <br>
# (1, Data Science)<br>
# (1, Computational Intelligence)<br>
# (2, Computational Intelligence)<br>
# (2, Linear Algebra)<br>
# (3, Analysis)<br>
# .....<br>

# %% [markdown]
# 10. Betrachten Sie die Relation TEACH mit den folgenden Abhängigkeiten:
#         - FD1: {Student_ID, Course_ID} → Teacher_ID
#         - FD2: Teacher_ID  → Course_ID
# Erstellen Sie das dazu passende Relationsschema in Boyce-Codd-Normalform (BCNF). (3 Punkte)
#
# Tabelle 4: TEACH
#
# | Student\_ID | Course\_ID | Teacher\_ID |
# | ----------- | ---------- | --------- |
# |        |       |        |

# %% [markdown]
# R1(Teacher_ID, Course_ID)
# Primary Key: Teacher_ID
# FD: Teacher_ID -> Course_ID
#
# R2(Student_ID, Teacher_ID)
# Primary Key: {Student_ID, Teacher_ID}

# %% [markdown]
# # Vorlesung 09: Verteiltes Datenmanagement

# %% [markdown]
#     1. Geben Sie die ACID-Eigenschaften an und beschreiben Sie bitte jede Eigenschaft mit Ihren eigenen Worten. (2 Punkte)

# %% [markdown]
# Die ACID-Eigenschaften sind:
# - Atomicity (Atomarkeit): Transaktionen werden entweder vollständig ausgeführt oder gar nicht.
# - Consistency (Konsistenz): Die Datenbank bleibt nach einer Transaktion in einem konsistenten Zustand.
# - Isolation (Isolation): Transaktionen beeinflussen sich nicht gegenseitig.
# - Durability (Dauerhaftigkeit): Nach dem Commit bleiben die Änderungen dauerhaft erhalten.

# %% [markdown]
#     2. Welche der folgenden Aussagen sind korrekt? (3 Punkte)
#
#         a) RDBMS konzentrieren sich auf Partitionstoleranz
#         b) NoSQL-Datenbanksysteme sind horizontal skalierbar
#         c) Die Ausführung einer Transaktion im RDBMS kann teilweise erfolgreich sein
#         d) Das Schlüssel-Werte-Datenmodell ist schnell & skalierbar
#         e) Das Wide-Column-Datenmodell ist nicht für Daten ohne klare Struktur geeignet
#         f) NoSQL steht für "No SQL at all"

# %% [markdown]
# a) ja. RDBMS sind nur schwer in klassischer sicht Horizontal skallierbar, da Spitzlasten oft bei einer hohen Rate an schnell aufeinanderfolgenden Anfragen anfallen, bei welcher Horizontale Skallierung nicht hilft. Deswegen werden Datenbanken je nach Szenarien in vertikale/horizontale Partitionen aufgeteilt.
#
# b) ja. NoSQL-Datenbanken bieten meist bessere Horizontal-Skallierbarkeit durch dezentrale Architekturen und verteilte Systeme, die es ermöglichen, Daten und Lasten über mehrere Server zu verteilen.
#
# c) nein. Ausführung einer Transaktion erfolgt entweder ganz oder garnicht.
#
# d) ja. Das Schlüssel-Wert-Datenmodell ist skallierbar.
#
# e)ja. da die Struktur intern nicht gewährleistet werden kann.
#
# f) nein. ->steht für not only sql, da viele systeme trotzdem weiterhin sql ähnliche Abfragen verwenden, nur der aufbau der internen struktur sich ändert

# %% [markdown]
# 3. Beschreiben sie in eigenen Worten den Unterschied zwischen vertikaler Skalierung (Scale-Up) und Horizontaler Skalierung (Scale-Out). (2 Punkte)

# %% [markdown]
# vertikale skallierung beziht sich auf ein einziges system welches aufgrund besserer Hardware-komponenten leistungsfähiger wird. Horizontale skallierung bezihieht sich darauf dass an ein bestehendes netzwerk weitere Systeme angefügt werden, womit das gesamte netzwerk leistungsfähiger wird.

# %% [markdown]
# 4. Geben sie das CAP-Theorems sowei seine Aspekte mit einer kurzen Beschreibung (natürlich in eigenen Worten) an. (3 Punkte)

# %% [markdown]
# C- Consistency/Konsisistenz
#     ->jeder leseforgang Arbeitet auf einem konsistenten(keine Beschädigten daten/abhängigkeiten) oder wirft einen Fehler
#
# A- Availability/Verfügbarkeit
#     -> jeder Lesevorgang bekommt eine Fehlerfreie Antwort, hierbei ist nicht garantiert dass diese auf dem neuesten Schreibstand ist
#
# P- Partition tolerance/Partitions-Toleranz
#     -> zwischen Netzwerknoten können belibig viele Verwefungen/verzögerungen auftreten (verschidene Knoten müssten Aufeinader warten)

# %% [markdown]
#     5. Nennen Sie die 3 Schritte des MapReduce-Programmiermodells und beschreiben Sie sie in Ihren eigenen Worten. (3 Punkte)

# %% [markdown]
# MAP-Phase:
# Schlüssel-Wert-Paare (einbagen) bekommen je nach suche einen wert zugeteilt
#
# Shuffle-Phase:
# Gruppierung der Werte nach Schlüssel
# -> Vorbereitung für Reduce-Phase
#
# Reduce Phase:
# Zusammenfassen von Werten mit gleichem Schlüssel
# -> Erzeugen finaler Ergebnisse

# %%
# 2 Punkte

def mapper(simulate_stdin):
    res = ""
    for line in simulate_stdin:
        line = line.strip()
        
        # Zerteilen Sie die Zeile in einzelne Wörter
        # YOUR CODE HERE
        words = line.split()
        
        # Hinzufügen von Wort und Häufigkeit
        for word in words:
            res += word + '\t1\n'
    return res

# %%
# 4 Punkte

def reducer(simulate_stdin):
    res = ""
    
    current_word = None
    current_count = 0
    word = None

    for line in simulate_stdin:
        line = line.strip()
        # Aufteilen des Inputs
        segs = line.split('\t')
        
        if len(segs) == 2:
            word = segs[0]
            count = int(segs[1])
        else:
            continue

        if current_word == word:
            # Erhöhen Sie den current_count
            # YOUR CODE HERE
            current_count += count
        else:
            if current_word:
                # Abspeichern im Ausgabestring
                res += current_word+'\t' + str(current_count) + '\n'
            # Updaten Sie current_word und current_count für das nächste Wort
            # YOUR CODE HERE
            current_word = word
            current_count = count
            
    # Das letzte Wort bei der Ausgabe nicht vergessen!
    if current_word == word:
        res += current_word+'\t' + str(current_count) + '\n'
    return res

# %%
docs = """
            Forrest Gump is a 1994 American comedy-drama film directed by Robert Zemeckis and written by Eric Roth. \n
            It is based on the 1986 novel of the same name by Winston Groom.\n
            The story depicts several decades in the life of Forrest Gump (Hanks), a slow-witted and kindhearted man from Alabama who witnesses and unwittingly influences several defining historical events in the 20th-century United States. \n
            The film differs substantially from the novel.
            """

# %%
assert mapper(docs.split('\n')) == 'Forrest\t1\nGump\t1\nis\t1\na\t1\n1994\t1\nAmerican\t1\ncomedy-drama\t1\nfilm\t1\ndirected\t1\nby\t1\nRobert\t1\nZemeckis\t1\nand\t1\nwritten\t1\nby\t1\nEric\t1\nRoth.\t1\nIt\t1\nis\t1\nbased\t1\non\t1\nthe\t1\n1986\t1\nnovel\t1\nof\t1\nthe\t1\nsame\t1\nname\t1\nby\t1\nWinston\t1\nGroom.\t1\nThe\t1\nstory\t1\ndepicts\t1\nseveral\t1\ndecades\t1\nin\t1\nthe\t1\nlife\t1\nof\t1\nForrest\t1\nGump\t1\n(Hanks),\t1\na\t1\nslow-witted\t1\nand\t1\nkindhearted\t1\nman\t1\nfrom\t1\nAlabama\t1\nwho\t1\nwitnesses\t1\nand\t1\nunwittingly\t1\ninfluences\t1\nseveral\t1\ndefining\t1\nhistorical\t1\nevents\t1\nin\t1\nthe\t1\n20th-century\t1\nUnited\t1\nStates.\t1\nThe\t1\nfilm\t1\ndiffers\t1\nsubstantially\t1\nfrom\t1\nthe\t1\nnovel.\t1\n'

# %%
# 1. Mapping
mapper_result = mapper(docs.split('\n'))

# 2. Shufflen
shuffled = sorted(mapper_result.split('\n'))


assert reducer(shuffled) == '(Hanks),\t1\n1986\t1\n1994\t1\n20th-century\t1\nAlabama\t1\nAmerican\t1\nEric\t1\nForrest\t2\nGroom.\t1\nGump\t2\nIt\t1\nRobert\t1\nRoth.\t1\nStates.\t1\nThe\t2\nUnited\t1\nWinston\t1\nZemeckis\t1\na\t2\nand\t3\nbased\t1\nby\t3\ncomedy-drama\t1\ndecades\t1\ndefining\t1\ndepicts\t1\ndiffers\t1\ndirected\t1\nevents\t1\nfilm\t2\nfrom\t2\nhistorical\t1\nin\t2\ninfluences\t1\nis\t2\nkindhearted\t1\nlife\t1\nman\t1\nname\t1\nnovel\t1\nnovel.\t1\nof\t2\non\t1\nsame\t1\nseveral\t2\nslow-witted\t1\nstory\t1\nsubstantially\t1\nthe\t5\nunwittingly\t1\nwho\t1\nwitnesses\t1\nwritten\t1\n'

# %%
import unicodedata

# Ausgabe des Ergebnisses von MapReduce:
def pretty_print(output):
    output = sorted(output.split('\n'), key=len)[1:]
    for word in output:
        word, count = word.split('\t')
        print('Wort: \033[1m' + '{0:20s}'.format(word) + '\033[0m Häufigkeit:  \033[1m' + count + '\033[0m -mal')
        
pretty_print(reducer(shuffled))

# Oder diese einfachere Version:
# print(reducer(shuffled))
# Out:
# Wort: a                    Häufigkeit:  2 -mal
# Wort: It                   Häufigkeit:  1 -mal
# Wort: by                   Häufigkeit:  3 -mal
# Wort: in                   Häufigkeit:  2 -mal
# Wort: is                   Häufigkeit:  2 -mal
# Wort: of                   Häufigkeit:  2 -mal
# Wort: on                   Häufigkeit:  1 -mal
# Wort: The                  Häufigkeit:  2 -mal
# Wort: and                  Häufigkeit:  3 -mal
# Wort: man                  Häufigkeit:  1 -mal
# Wort: the                  Häufigkeit:  5 -mal
# Wort: who                  Häufigkeit:  1 -mal
# Wort: 1986                 Häufigkeit:  1 -mal
# Wort: 1994                 Häufigkeit:  1 -mal
# Wort: Eric                 Häufigkeit:  1 -mal
# Wort: Gump                 Häufigkeit:  2 -mal
# Wort: film                 Häufigkeit:  2 -mal
# Wort: from                 Häufigkeit:  2 -mal
# Wort: life                 Häufigkeit:  1 -mal
# Wort: name                 Häufigkeit:  1 -mal
# ...
